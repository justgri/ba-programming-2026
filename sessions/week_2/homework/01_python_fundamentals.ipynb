# %% [markdown]
# # Python Fundamentals — Exercises
#
# Write code in the cells below. Uncomment the examples to print your results.
# The first six topics follow the lecture; loops, functions, and comprehensions provide further practice.

# %% [markdown]
# ## Notebook Basics

# %% [markdown]
# ### 0.1
#
# Add a Markdown heading and a code cell. Print `"Python practice"`, add a comment, and run the code with Shift+Enter.

# %%
# TODO

# %% [markdown]
# ## 1. Object Types

# %% [markdown]
# ### 1.1
#
# Assign one value of each type: `bool`, `int`, `float`, `str`, `list`, `tuple`, `dict`, `set`. Print their types.

# %%
# TODO

# %% [markdown]
# ### 1.2
#
# Convert `"18"` to an integer, `"2.75"` to a float, and `36` to a string. Store the results as `count`, `price`, and `label`.

# %%
# TODO

# Examples: uncomment after completing the exercise.
# print(count)  # Expected: 18
# print(price)  # Expected: 2.75
# print(label)  # Expected: '36'

# %% [markdown]
# ### 1.3
#
# Predict the output, then run the cell. Create a temporary variable, delete it with `del`, and check that reading it raises NameError. Comment out the failing line afterwards.

# %%
original = 14
copy = original
original += 6
print(original, copy)

# TODO

# %% [markdown]
# ## 2. Indexing & Slicing

# %% [markdown]
# ### 2.1
#
# Extract `"data"`, `"csv"`, and every second character from `filename`. Reverse the string.

# %%
filename = "data_2026.csv"

# TODO

# %% [markdown]
# ### 2.2
#
# Print the first item, last item, middle three items, and final two items. Repeat with a tuple containing the same values.

# %%
values = [8, 3, 12, 5, 9]

# TODO

# %% [markdown]
# ### 2.3
#
# Read `"green"`, change it to 7, and add `"yellow": 4`. Look up `"black"` with `.get()`, returning 0 if absent.

# %%
counts = {"red": 3, "green": 5, "blue": 2}

# TODO

# Examples: uncomment after completing the exercise.
# print(counts['green'])  # Expected: 7
# print(counts['yellow'])  # Expected: 4
# print(counts.get('black', 0))  # Expected: 0

# %% [markdown]
# ## 3. Basic Operations & Built-in Functions

# %% [markdown]
# ### 3.1
#
# Calculate `a + b`, `a - b`, `a * b`, `a / b`, `a // b`, `a % b`, and `b ** 3`.

# %%
a = 29
b = 4

# TODO

# %% [markdown]
# ### 3.2
#
# Strip outer spaces; produce lowercase, uppercase, and title-case versions. Split the cleaned text into words. Replace only the first `"a"` with `"@"`.

# %%
text = "  Data ANALYSIS basics  "

# TODO

# %% [markdown]
# ### 3.3
#
# Join the two strings with a space using `+`. Print `"ha"` four times using `*`. Use an f-string to print `"Version: Python 3"`.

# %%
language = "Python"
version = "3"

# TODO

# %% [markdown]
# ### 3.4
#
# Print the length, minimum, and maximum. Create a sorted copy, then sort the original in descending order. Append 6 and extend with `[1, 4]`.

# %%
numbers = [18, 7, 25, 12]

# TODO

# %% [markdown]
# ### 3.5
#
# Append `"c"` through `alias`; remove `"a"` from `separate`. Print all three lists. Compare `==`, `is`, and `id()` before and after the edits.

# %%
items = ["a", "b"]
alias = items
separate = items.copy()

# TODO

# Examples: uncomment after completing the exercise.
# print(items)  # Expected: ['a', 'b', 'c']
# print(separate)  # Expected: ['b']
# print(alias is items)  # Expected: True
# print(separate is not items)  # Expected: True

# %% [markdown]
# ### 3.6
#
# Convert `.keys()`, `.values()`, and `.items()` to lists. Print each result and the type of its first item.

# %%
scores = {"A": 12, "B": 8, "C": 15}

# TODO

# %% [markdown]
# ### 3.7
#
# Find the union, intersection, and both set differences. Add 10 to `left`. Remove an arbitrary item from a copy with `.pop()`.

# %%
left = {2, 4, 6}
right = {4, 6, 8, 9}

# TODO

# %% [markdown]
# ## 4. Booleans & Conditionals

# %% [markdown]
# ### 4.1
#
# Set `allowed` to True only when `registered` is True and either `open_now` or `has_key` is True. Print `"Allowed"` or `"Denied"`. Try different boolean inputs.

# %%
registered = True
open_now = False
has_key = True

# TODO

# %% [markdown]
# ### 4.2
#
# Classify a positive integer as `"small"` (1–8), `"medium"` (9–16), or `"large"` (17+). Use `if` / `elif` / `else`. Check 8, 9, 16, and 17.

# %%
size = 12

# TODO

# %% [markdown]
# ### 4.3
#
# Print the first list item if the list is non-empty; otherwise print `"Empty"`. Repeat with `[]`. Print the boolean values of `0`, `1`, `""`, and `"abc"`.

# %%
values = [4, 9]

# TODO

# %% [markdown]
# ## 5. File Input/Output

# %% [markdown]
# ### 5.1
#
# Using `pathlib.Path`, write `text` to `practice_input.txt` in the working directory with UTF-8 encoding. Read it back and print the lines using `.splitlines()`.

# %%
text = " alpha \n\nbeta\n gamma  \n"

# TODO

# %% [markdown]
# ### 5.2
#
# Read `practice_input.txt` from 5.1. Use a loop to strip each line and skip blanks. Write the remaining lines in uppercase to `practice_clean.txt`, separated by newlines.
#
# Expected file contents: `ALPHA`, `BETA`, `GAMMA`, each on its own line.

# %%
# TODO

# %% [markdown]
# ## 6. Importing Libraries & Local Scripts

# %% [markdown]
# ### 6.1
#
# Import `math`. Calculate the square root of 144 and round 19 / 8 upward with `math.ceil()`. Import `random` and generate an integer from 1 through 6, inclusive.

# %%
# TODO

# %% [markdown]
# ### 6.2
#
# Import NumPy as `np`. Convert `values` to an array. Print its size, dimensions, mean, sum, and cumulative sum. If needed, install NumPy in a separate cell with `%pip install numpy`.

# %%
values = [3, 0, 4, 2]

# TODO

# %% [markdown]
# ### 6.3
#
# Create `practice_helpers.py` in the working directory containing `factor = 3`. Import the module and print `practice_helpers.factor * 8`. Then import `factor` directly with `from ... import ...` and repeat the calculation.

# %%
# TODO

# %% [markdown]
# ## 7. Loops

# %% [markdown]
# ### 7.1
#
# Loop over integers 1 through 8. Print each number and `"odd"` or `"even"`, using `%` and an f-string.

# %%
# TODO

# %% [markdown]
# ### 7.2
#
# Use a for loop to calculate `total` without `sum()`. Print the running total after each addition.

# %%
values = [25, 40, 35, 20]
total = 0

# TODO

# Examples: uncomment after completing the exercise.
# print(total)  # Expected: 120

# %% [markdown]
# ### 7.3
#
# Collect values from 12 through 24, inclusive, in `selected`. Preserve their order. Count values below 12 in `below`.

# %%
values = [8, 12, 30, 18, 24, 10]
selected = []
below = 0

# TODO

# Examples: uncomment after completing the exercise.
# print(selected)  # Expected: [12, 18, 24]
# print(below)  # Expected: 2

# %% [markdown]
# ### 7.4
#
# Starting at 15, add 12 repeatedly until `value` reaches or exceeds 74. Use a while loop and count iterations in `steps`.

# %%
value = 15
steps = 0

# TODO

# Examples: uncomment after completing the exercise.
# print(value)  # Expected: 75
# print(steps)  # Expected: 5

# %% [markdown]
# ### 7.5
#
# Ask for text repeatedly with `input()`. Strip outer spaces. Stop on `"stop"`, skip blank entries, and print all other entries in uppercase. Use `break` and `continue`.

# %%
# TODO

# %% [markdown]
# ## 8. Functions

# %% [markdown]
# ### 8.1
#
# Return the text stripped, lowercased, and with spaces replaced by hyphens.

# %%
def make_key(text):
    pass

# TODO

# Examples: uncomment after completing the exercise.
# print(make_key('  Data Analysis '))  # Expected: 'data-analysis'

# %% [markdown]
# ### 8.2
#
# For a non-negative integer duration, return `(hours, remaining_minutes)`. Unpack one result into two variables.

# %%
def split_duration(minutes):
    pass

# TODO

# Examples: uncomment after completing the exercise.
# print(split_duration(95))  # Expected: (1, 35)
# print(split_duration(60))  # Expected: (1, 0)

# %% [markdown]
# ### 8.3
#
# Return True if the number is divisible by 3; otherwise return False.

# %%
def multiple_of_three(number):
    pass

# TODO

# Examples: uncomment after completing the exercise.
# print(multiple_of_three(12))  # Expected: True
# print(multiple_of_three(14))  # Expected: False

# %% [markdown]
# ### 8.4
#
# Return `(total, average)` for a list of numbers. For an empty list, return `(0, None)`.

# %%
def summarise(values):
    pass

# TODO

# Examples: uncomment after completing the exercise.
# print(summarise([2, 0, 4]))  # Expected: (6, 2.0)
# print(summarise([]))  # Expected: (0, None)

# %% [markdown]
# ### 8.5
#
# Return a sorted list of unique values in `required` that are absent from `available`. Use sets.

# %%
def find_missing(required, available):
    pass

# TODO

# Examples: uncomment after completing the exercise.
# print(find_missing([3, 1, 3, 5], [1, 2]))  # Expected: [3, 5]
# print(find_missing([], [1]))  # Expected: []

# %% [markdown]
# ### 8.6
#
# Complete the helpers and dispatcher:
#
# - `difference(a, b)`: return `a - b`.
# - `percentage(a, b)`: return `a / b * 100`, or None if `b == 0`.
# - `calculate(a, b, operation)`: call the matching helper for `"difference"` or `"percentage"`; return None for other operations or non-numeric inputs. Assume booleans are not supplied.

# %%
def difference(a, b):
    pass


def percentage(a, b):
    pass


def calculate(a, b, operation):
    pass

# TODO

# Examples: uncomment after completing the exercise.
# print(calculate(15, 20, 'difference'))  # Expected: -5
# print(calculate(15, 20, 'percentage'))  # Expected: 75.0
# print(calculate(1, 0, 'percentage'))  # Expected: None
# print(calculate('1', 2, 'difference'))  # Expected: None
# print(calculate(1, 2, 'other'))  # Expected: None

# %% [markdown]
# ## 9. Comprehensions

# %% [markdown]
# ### 9.1
#
# Use a list comprehension to convert minutes to hours.

# %%
minutes = [30, 60, 90, 120]

# TODO

# Examples: uncomment after completing the exercise.
# print(hours)  # Expected: [0.5, 1.0, 1.5, 2.0]

# %% [markdown]
# ### 9.2
#
# Build `cleaned` with stripped, lowercase strings. Omit entries that are blank after stripping.

# %%
labels = [" One ", "", "  ", "TWO", " Three"]

# TODO

# Examples: uncomment after completing the exercise.
# print(cleaned)  # Expected: ['one', 'two', 'three']

# %% [markdown]
# ### 9.3
#
# Use a dictionary comprehension to map each word to its length.

# %%
words = ["data", "loop", "function"]

# TODO

# Examples: uncomment after completing the exercise.
# print(lengths)  # Expected: {'data': 4, 'loop': 4, 'function': 8}
